# %% [markdown]
# # Práctica 7.1. Generación de texto con LSTM
#
# Como primera toma de contacto con modelos generativos, en esta práctica vamos a ver cómo generar texto aleatorio con LSTM.
#
#
# ## 1. Implementando generación de texto con LSTM a nivel de caracter
#
# Lo primero que necesitamos son muchos datos de texto que podamos usar para aprender un modelo de lenguaje. Podrías usar cualquier archivo de texto suficientemente grande o un conjunto de archivos de texto como Wikipedia, El Señor de los Anillos, etc. En este ejemplo utilizaremos algunos de los escritos de Nietzsche, el filósofo alemán de finales del siglo XIX (traducido al inglés). El modelo lingüístico que aprenderemos será, por lo tanto, específicamente un modelo del estilo de escritura y de los temas de elección de Nietzsche, en lugar de un modelo más genérico de la lengua inglesa.

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# '2.2.4'

# %% [markdown]
# ## 2. Preparando los datos
#
# Comencemos descargando el corpus y convirtiéndolo a minúsculas:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %% [markdown]
# A continuación, extraeremos secuencias parcialmente superpuestas de longitud `maxlen`, las codificaremos con one-hot encoding y las empaquetaremos en una matriz 3D Numpy `x` con shape `(sequences, maxlen, unique_characters)`. Simultáneamente, preparamos una matriz `y` que contiene los objetivos correspondientes: los caracteres codificados con one-hot que vienen justo después de cada secuencia extraída.

# %%
# Longitud de las secuencias de caracteres extraídas
maxlen = 60

# Muestreamos una nueva secuencia cada `step` caracteres
step = 3

# Esto almacena nuestras secuencias extraídas
sentences = []

# Esto almacena los targets (el siguiente caractar)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# Lista de caracteres únicos en el corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# El diccionario que asigna caracteres únicos a su índice en `chars`.
char_indices = dict((char, chars.index(char)) for char in chars)

# A continuación, codificación one-hot de caracteres en arrays binarios
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## 3. Construyendo la red
#
# Nuestra red es una única capa `LSTM` seguida de un clasificador `Dense` y softmax sobre todos los caracteres posibles. Pero notemos que las redes neuronales recurrentes no son la única manera de generar datos de secuencias; los convnets 1D también han demostrado ser extremadamente exitosos en los últimos tiempos.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# Dado que nuestros objetivos están codificados con one-hot, utilizaremos `categorical_crossentropy` como función de pérdida para entrenar al modelo:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## 4. Entrenamiento del modelo lingüístico y muestreo del mismo
#
# Dado un modelo entrenado y un fragmento de texto de semilla, generamos nuevo texto repetidamente:
#
# * 1) Tomando del modelo una distribución de probabilidad sobre el carácter siguiente dado el texto disponible hasta el momento.
# * 2) Revaluación de la distribución a una determinada "temperatura".
# * 3) Muestreo aleatorio del siguiente carácter de acuerdo con la distribución reponderada
# * 4) Añadir el nuevo carácter al final del texto disponible
#
# Este es el código que usamos para reponderar la distribución de probabilidad original que sale del modelo, y extraer un índice de caracteres de él (la "función de muestreo"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finalmente, este es el bucle en el que entrenamos y generamos texto repetidamente. Comenzamos a generar texto usando un rango de temperaturas diferentes después de cada época. Esto nos permite ver cómo evoluciona el texto generado a medida que el modelo comienza a converger, así como el impacto de la temperatura en la estrategia de muestreo.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Adaptar el modelo para 1 época a los datos de entrenamiento disponibles
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Seleccionar una semilla de texto al azar
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # Generamos 400 caracteres
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 1.9767
# --- Generating with seed: "the beginning, and that even the severest way of life may be"
# ------ temperature: 0.2
# the beginning, and that even the severest way of life may been the exception of the something and the conternonce of the sense of the sumplent of the same and the says and contempt of the soul as a more one which as a this and the exound and the sand the soul of the schereand the schould and the existing the spirits of the conterning the soul and the soul the existing the spirits of the conterning and the sense and the soul and the soul and the sensity of
# ------ temperature: 0.5
#  and the sense and the soul and the soul and the sensity of the contempt from then thear the exceptions of the experient of the conternanition of the soness of the soul does the who are the sain them in the existente and can one as the
# schould in the secremently in they which the simely with a moral some and the conscioush and and and this conscience be something and from the sond and the every the arthing from stand souls about which we the concorditite o
# ------ temperature: 1.0
# e arthing from stand souls about which we the concorditite of liverate , alth estents existion
# opintully
# my very : this cormstance,
# our and which men clathy and pridesce, orditungite belanves. these which scientive of which as not reals of his not it hiader, all by this, east had
# frel
# hardsally wood id dongrus?fund, this his adance, in their have not a lond but ale comention of red them"e--this as most and dicces theyp ever up unte it in faech jush seeding
# ------ temperature: 1.2
#  most and dicces theyp ever up unte it in faech jush seeding
# not nots atthrmaded exvility
# themq"--so -thing quists. it
# framerd and ofdgenohtut doble one'
# one in arine--"perhosdels enstiment,
# and lighiny and which in thatking, conhecsans. unewarnshis, in "he waisd as aupy auk thinses this nature we
# pomsheect: must my
# and
#
# yey withly ands, this beaned zothical fulntled
# the
# would, then amenamitation so nce
# swongius hilsind who conteityes elarticl, thus firsce
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.6202
# --- Generating with seed: "ious
# people, a sum total of the doings of conscious and will"
# ------ temperature: 0.2
# ious
# people, a sum total of the doings of conscious and will of the spirit of the spiritual supposition of the still the spirit of the science of the spirit of the spirit of the most man the spirit of the spirit of the seems of the spirit of the spirit of the supersious the spirit the spirit of the spirit of the spirit of the spirit of the science of the seems of the senses to the seems the spirit of the spirit of the science of the spirit of the most of t
# ------ temperature: 0.5
#  of the spirit of the science of the spirit of the most of the econsers, it is almost believe and object of the most present believe the there asontiming intermination of supposed to one is and science of the will of the
# sumpt man with its will of the seems the companding, the terman and the science to be and the belief the action of the world of the science of the spirit, and the development of the morality first the bad of the and this science to and sci
# ------ temperature: 1.0
# he morality first the bad of the and this science to and scir
# taste why
# and as because as fran amt from with formul actions of they intermany--has to gettions."--the pry sacre singlans it lines of their gorms to
# mankind
# by noble: the anastic follos essentiments of this words nom this dayment
# him discapri. and bad persed in respicial tiacrifier one ugnoutable power, rothing
# of oul as so of one him ancistance in diedius occaps it to live which no recognise,
# ------ temperature: 1.2
# ancistance in diedius occaps it to live which no recognise, this appear who putses, occesoumsusit smegutesness upon
# empoces thesesfrom orness tarde an
# turiationally restacity belos
# go vo that
# doved phopes? himselves wo
# lta, man
# truth, se tioraus to irmptipnrumous truch
# to faie, toet new.
#
#
#
#
#
# countwist
# of gardady eughtrans, to command,
# mostise from bcivauld altpumatesly: for religions, the from dastt sisnituhas the spirit, stigutt, thene soitatouliand?clin
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.5352
# --- Generating with seed: "on of the type "man," has hitherto been the work of an
# arist"
# ------ temperature: 0.2
# on of the type "man," has hitherto been the work of an
# aristor the german soul of the existence of the spirit the spirit be an interpochty of the exceptions of the spirit the spirit of the spirit of the spirit the spirit of the spirit of the spirit of the spirit of the self-spirit of the supernglation of the spirit of the spirit of the event the sentimate the spirit of the spirit the spirit of the spirit the spirit of the spirit to the spirit and the spiri
# ------ temperature: 0.5
#  spirit the spirit of the spirit to the spirit and the spirit of the special supporition of the spirit the free spirit one should the contempt of the superfith the intellectuality and the still condition is life and most preous that the spirit of the
# strucctures of the superior in the delication of the sendition of a condition of the more all the superficting, are all the emplacations of the labks of the condition of the struccitural present of the conditi
# ------ temperature: 1.0
#  of the condition of the struccitural present of the conditions. which many the intellectual fear of theyes and its will backs of thenk abirtatier he also to reasboly, the idealical wilders
# and itally xign of the eliey of intelforness it others. thrists. in priof, himself rects and for one
# callith the refreed,
# consciences and
# nowadays
# wicks by "natureful daborcation
# and distriat" alws of ah.
#
# =ceave, able then with he fenited ersil, something
# may suffer an
# ------ temperature: 1.2
# ve, able then with he fenited ersil, something
# may suffer anviet-man "esletsike with clousy his dostarxage, it just--they perhaps axtrance of the.-"
# weiny, then, if whoever curneculd: ye mire if however, effect-conifade" now humans" the conscience, and betribent midiums comtard only grosth, we rewicination of : effect of edelisd for ot immosturar from many by "the
# soul permectures mosived, like "mankind, event--it is would beenles, the
# home--i manifesled t
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.4900
# --- Generating with seed: "egular cult of
# suffering. the unmanliness of that which is c"
# ------ temperature: 0.2
# egular cult of
# suffering. the unmanliness of that which is conscience of the same the same the same the sought and the spirit of the great the same the same the same and the sense of the content of the state and the great the stime of the great and the belief of the same the same the same and age and the scientific and and the fact, and the same the problem and the spirit of the same the same the far and against the same the same the commencess of the same
# ------ temperature: 0.5
# far and against the same the same the commencess of the same who are all stronger of the stand the school, and the supposition of the man their has a very be seeks or the morality and the greek and the sought the same the power to the
# problem and something contains and family to its the philosophers: they has at fir is the proprean of the most and be sense enconsistents and without stronger in be deperamptant in the body and hand of even and benevise on th
# ------ temperature: 1.0
# deperamptant in the body and hand of even and benevise on the powerful awe metimoss? which connound,
# can reinges, something, preake author, which probuwty of fact me no naw the regard of no wolleis with or doman mean for let, it we ages, it see eal of contest, which probour and ow
# and which soughtle ethically to be possible condied, i besine about pali at
# growtroming
# and itselfally, be reckent:--the groed
# into the moralike--the similaveis different, and co
# ------ temperature: 1.2
# he groed
# into the moralike--the similaveis different, and cormonally more scientif
# -achifeed the prochws to tolecr at the
# wan syetnisse upon i nritulely have pa tamered
# age? are sppare
# oldmenly, in errminivy, at morbarity recigle reabvengate
# that ariocacy: this else--merelantive, that this, all ourtasters bly himself is might, there iss but powerfulnegate
# ciull peopleius prifofiousness, and
# it men to rerevaioe
# gaves--which the
# scientif,
# alther prisonsq? th
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.4604
# --- Generating with seed: "physical and
# historical explanations would, at least, have g"
# ------ temperature: 0.2
# physical and
# historical explanations would, at least, have greatest and state and self-serven in the state of the state of the strength and the strength and the state of the self-severtion of the state and the strength and the strength and the self-serven and something of the consideration of the conscience of the still the strength of the strength and man and the strength and all the still the strength and the strength of the all the still be one of the s
# ------ temperature: 0.5
# rength and the strength of the all the still be one of the strengthers contempt of the species of the surreare of the still believe theme all the greatest of a propers of the spiritual to his self-most really and state in the serve the sign of the stoul man has to serves and development of the case of the developed on the still better and greatest morality of strength, the love of the emory of a conscience to
# sense of the medigided and him the man is a sys
# ------ temperature: 1.0
# onscience to
# sense of the medigided and him the man is a system and delightwer, exartion? it is all exist sus it in there as nature of amoration peopay in
# the its excenity the peterenced and because which shares to the workting theodor world be
# noble withit we go
# being, no ise trisses inconitequestage one other con the once
# a vantwa, with the speri cruelty of all
# repulsed appavences the
# dace! lose gright, and authowen redomplered in science with one; not n
# ------ temperature: 1.2
#  gright, and authowen redomplered in science with one; not not to
# by betreation as not disunounce to po
# sity. the peopal in a known of praisonsdvent mestical, reveale takes modern its freedomment. but in itmanger,, lendenest heartly
# mundce of alevere finalm of exist: but has 1'herwabstanine, is that as he sove stack of the everviced, whichs strune and rick. oode: an a well gright pertain beings without exest ye coares and sacrue with alluration measualityh
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.4405
# --- Generating with seed: "egation of life--there is,
# as is generally acknowledged nowa"
# ------ temperature: 0.2
# egation of life--there is,
# as is generally acknowledged nowadays of the expression of the really and assign of the seriousness of the more so that it is the servile of the expression of the same that a sort of the same that a so that a such a sense of the same the spirit of the spirit of the conscience of the experience of the serious spirit and all the exception of the same that it is not probleme that a philosophers of the spirit of the same thing and in
# ------ temperature: 0.5
# e that a philosophers of the spirit of the same thing and interrast the close entirely the one of the servile of all the spirit for origin, it was the profound of all more grateful and german do which and the bad as a truth and was a science of the from the philosophy of which the virtues. we now is to be not of the resting of the dream. they are in the world has and all the exception of the form of experience of pretatery can for such anyout that the lack
# ------ temperature: 1.0
# of experience of pretatery can for such anyout that the lacking--will is nothlought.
#
#
# dea-twarding, but--which and no .re--himself of art of such all capact of challour not a spirity bevere good follator meatts conditicity that is is
# our depression of the bad noble: one of the appyst and so she sacrifice of preusility,  vortures may look eleval, will partly, 2quitidely and
# enforming cruch in hellekis; less sequence to owing to attente of that emposses.=--
# ------ temperature: 1.2
# ekis; less sequence to owing to attente of that emposses.=--through
# slonerve herw, he,
# insame in phrios, as thee aroration and let keory, him
# ole, tain-condingerve,es churseds lage again tactirable offord, and also song=aqa(by why the lookick are people modeally increasisbin wile, agdessromer--impulse of the most party to be
# to preserved hard ownes: say. on all the latterly accuative carry in thb -threse" ode of niplicity. on it, noibicial forgetnariry! is
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.4218
# --- Generating with seed: "developes the unwise, irrational, guilt-conscious
# man--that "
# ------ temperature: 0.2
# developes the unwise, irrational, guilt-conscious
# man--that the sense of the fact of the strohic of the still and the false of the sense of the faith and the sense of the spirit of the state and souther and the spirit of the commands of the german of the still and souther in the moral in the existence of the higher are something as a souther the fact of the experiment of the still and destruction of the sense of the still of the strong of the spirit of the
# ------ temperature: 0.5
# of the sense of the still of the strong of the spirit of the morality of the strocie itself of the love of the still and interestor of the mostiment of order the personal certain something in error of the conscience in a conscience of the state lach its lightly belong: and in the exeacis of the conscience, and the extent the father which the same faith the most upperhaps the general personal sense of the sense of the senses and the best sour the conscience
# ------ temperature: 1.0
#  of the sense of the senses and the best sour the consciences of every on the uptimermiaay
# time (parted the cause with some
# o; the discupition which case forta's
# false to represince outmourable imbacie tilld-natures--serves virtuesly, which agreenaly, the undest his animanity of tonegrumed remained: understooding
# myrelk for them appearing--thought! and
# "persiss estimate
# seedvke is conversionrourrity is belong; heeld in which over which one have are not ech
# ------ temperature: 1.2
# ty is belong; heeld in which over which one have are not echtem of human witnon smilled his jeadnce, in discivine of
# coyities and neferation. as did the po stage hear precisementment of very evilselesm is descirital persons, they demoudncionkus book utier that it would my higher prooful a
# mystalize skee itself reference to his satowide cleat otheses, medion in old difticulawer,
# othery constanch of hiscolomical him--what
# a luckques, attrmmant itsals avere o
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.4095
# --- Generating with seed: "fore, just as sensations (and indeed many kinds of sensation"
# ------ temperature: 0.2
# fore, just as sensations (and indeed many kinds of sensation of the servile to be does and and there is not all the sense of the morals of the sense of the more far and the sense of the reason of the consequs of the falsehorism the sense of the consequence of the experiences the heart of the consequence of the power and the man himself which a man of the same the strong of the sense of the far an antiquity of the best and serious and precisely the things a
# ------ temperature: 0.5
# antiquity of the best and serious and precisely the things and counter there
# are have one an instance, the conceptions to science of the course of the path under this summ
# complese in the facts and in the consequenced which matter and complication of the falseh of here one must man, as in the jesile of the standating experiences (and all the spirit of the deacht prepared by the one of the might and new exeed a german in the consests and ane far one is prev
# ------ temperature: 1.0
# d new exeed a german in the consests and ane far one is previously, how all indean or for into wild, three
# withny the stated without higher. whether and assyous
# continuoy, profounda--adarcy--ourn aver--which, while
# best witholy
# intellection upon the
# ellsued and patilitions, i oncivered--in order ineld as laok ochseless the sees andadwance. have
# sothity of modern the qui estimatesm of
# dea virtues and "manivorable here" in these rosped to me, oh theirms of
# a
# ------ temperature: 1.2
# nd "manivorable here" in these rosped to me, oh theirms of
# all averis, why one ha rease." these adart of condogadd, as preisht
# acts how for supjing the spicies,, in their facts
# and origorow with they has on
# mudip, comper one old an agiss, for course, a
# supporthd
# vassing no ichipse ebli extent of their intoldenow theo: throwhes trantsk
# mista-been muss holy concescure of "intiolbje, that must weight: the very supertion, manigiblenels ase, aconred to be power
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3959
# --- Generating with seed: "n the part of grammar, or an
# audacious generalization of ver"
# ------ temperature: 0.2
# n the part of grammar, or an
# audacious generalization of very the subjus there is the sense of the sense of the self-sense of the sense of the history of the sense of the same the same the same the same the superiority of the same the sense of the self-sense of the same that the sense of the same the self-sense of the most and all the sense of the same the sense of the sense of the self-sense of the same in the same the self-sense of the self-sense of the
# ------ temperature: 0.5
# he same in the same the self-sense of the self-sense of the demand and a same the sense of the live in the englishes the intentioner thinkeness of the same and
# has not been of the subjumable short, he may be a bear as a man with a man and the german conterd as a thing that they in the present that we the charming that they may be the cruely and
# also which the disclose the man and the here that the antide of a superior and even the care a man in the highten
# ------ temperature: 1.0
#  antide of a superior and even the care a man in the hightend. the his besting because anare--at present upon enders
# virtue: whether further persisting
# as the genviling of the erroriss.
#
# sole the or falsificiwa7ited. the solificed o"--which oaking of the senses towards strived within rescille cofless that they has his quighlees a moral belier that the persicty to be indealwinges.
#
# 17art of the satisfaction art of eventive would,"--religion.chelence in disf
# ------ temperature: 1.2
# isfaction art of eventive would,"--religion.chelence in disfitive all divine preed thinly. what is just he nothers varie from mistakingment upourtiblly if my hos to booders,--the truth upou terrolowing, iness
# consideration, we muse govew!
# sore shameness has every tami of their mines, o, it wanture of strugglech, act, is the umpulse for eur law is not only those cracticention, alshe forth just the nait
# in oud qualitive errorc which, if the most called "then
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3879
# --- Generating with seed: "
# (as, for instance, in the case of hygienic science) as to i"
# ------ temperature: 0.2
#
# (as, for instance, in the case of hygienic science) as to intermined to the sense of the superior and superficial and all the ages, and the sense of the sense of the sense of the agest of the sense of the state of the really and the same to the sense of the most profound in the self souls and something the sense of the sense of the sense of the sense of the sense of the sense of the last and the present and the sense of the sense of the most property that
# ------ temperature: 0.5
# present and the sense of the sense of the most property that which the evils is necessary of an experience in the seek of thinker of the desire in the conception of the property that the end and nature of the sense of whold stand, the god and done: in his personal instinct and
# assumed in adore of the spirit in the emoriated and the desirable mediocrion in the earth to present mankind may not as what so event the stronger and become the stronger modes it ar
# ------ temperature: 1.0
# at so event the stronger and become the stronger modes it are exped to alls, what
# pain and enisiet way on them; and wese excite oneituiven the secome pacity of god" one of a insigniat anything knowledge, books and sender of learness of echolsl, where; no replined of self
# so sign mad then thus, and for perhaps present with artistic ears love to the
# feas: "the rumane
# share just chri4.--it is creedinataps, convoncy to inbeut magicy, and measure of desilineus.
# ------ temperature: 1.2
# ataps, convoncy to inbeut magicy, and measure of desilineus.
# which this species wrich a ber in satillihtived which, means in power!celeans." as wet whose stys
# thorselentth reason--inlatceven. will bork, he wantle girdid, and bolke upperty has now sipation, to know oftenly velind eonobo, the fase and ambingthaus, which he, a much overquingleness from healthing soin and their
# surplakes sosely, spier to a morality, to have god
# would know, that the god conduct
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3800
# --- Generating with seed: "edge") than the impia fraus.
# hence the profound lack of judg"
# ------ temperature: 0.2
# edge") than the impia fraus.
# hence the profound lack of judging of the sense of the sense of the same to the faculty of the same to the spirit and the sensitions of the same to the sense of the conceals of the same to the faculty of the enough and the spirit and the spirit and the present that the same to the spirit and the same to the present of the same to the conceals of the respectic of the sense of the way to the spirit and the most present the same t
# ------ temperature: 0.5
# nse of the way to the spirit and the most present the same to the the same to in the morality of the same the present concernined to the faculalism and that here concernine of the same to sensible, the spirit and something to the purpose and spirit and the
# sense of the sout" be a most most to his agains the knowledge and most precisely the conceptions and were nothing that to conceive the famous and precisely a more opposed the fastord that a sough and phi
# ------ temperature: 1.0
# nd precisely a more opposed the fastord that a sough and philosophy period is the entirely hundection of the "european into the again symptom to conventine have no  aal? matiencely gundesly that li:e. alth(ander "noil howes persen homedient a docurs of the fastorable
# that. there are matter of
# the we acts as we hear
# the will to spends, in theur the anceprefund to plain who were thene have those to the incase whone be fraugin fame free new concernines--but t
# ------ temperature: 1.2
# the incase whone be fraugin fame free new concernines--but there have with perceived matery. see go
# gigstality concertarily verculestfeque of amm i to his too thre; herms, and fondefbeed in which
# recoduces--willicsy, or some phyo--this suftruteril instinction aitwiept hit.--norition of the dropactives "sublimateping
# ou them.
# of poreant given thail ourselvesle patibling spiritblee incovered most experience of suchaceted) of piy hardi
# of --that
# kancielabun,
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3707
# --- Generating with seed: "ce of a diversified descent in his
# body--that is to say, con"
# ------ temperature: 0.2
# ce of a diversified descent in his
# body--that is to say, continual and superficies of the stimpt to the standard and the spirit and as a spirit in the present and some high stiped to be a superficies and in the excess of the spirit of the spirit to many the spirit and the man is a souls of the contempt of the spirit of the sense of the contempt to the most distrust of the spirit and all the exception of the spirit and the standard and the spirit and some o
# ------ temperature: 0.5
# ion of the spirit and the standard and the spirit and some oke and sense of the new reason of the spirit to is allameness of the errones; or as some stipentary and conditions of the still
# surmince is a person of the man concerns and all the seductives in a fail away to his own imposses to his same allow which the play in our god, the things and exception to the spirit of souls of the unintermines of which is not frather and
# the generation of the basisely a
# ------ temperature: 1.0
# of which is not frather and
# the generation of the basisely affordings wimndaning and human
# haid with an explengingness that will abpourceious for habit to spyling endom, conclusions, however, we provided: the came; their reveres these one else)," they dire own, the antithous piesty and dreamsful. will we being man as him.
#      that may be a will to spirit he want of human eyingmen,
# and vibqurntly souls of
# a lough some gurbous damated, which the mode, has
# ------ temperature: 1.2
#  souls of
# a lough some gurbous damated, which the mode, has no
# standpure will
# weope toqued dial perhaps in
# putsian to the
# ideally
# contemplation-
# alarble, allwing, and their
# innoce. if,
# every proveslipe.=--but "maw of hour, inkems
# and religirt-patehd mredularies to rictly und every dwain" hightrimus.ter
# ord, in his oftication, emb a veone will ao hypotsile may coming aport of the dove stimned
# upon is, and overtut"
# to me"ter
# whelematk, these art
# often on iun
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3649
# --- Generating with seed: "en very
# much plagued by his passions and vices, longs to fin"
# ------ temperature: 0.2
# en very
# much plagued by his passions and vices, longs to find the same things and consequences of the same the sense of the consequence of the sense and proposition of the sense of the same the spirit the sense of the contrary of the sense of the same that the sense of the sense of the self-possible the same to the sense of the self-sense of the sense of the end and the end and souls of the same to the sense of the consequence of the sense of the self-cont
# ------ temperature: 0.5
# o the sense of the consequence of the sense of the self-contrary and moral has sympathy and consequence which the heart of the conscience
# must be so the consequence" is when it has vengerative contrary minds the same that should place into muchs and men, the property the fastes that we has been any allow themselves
# the domain and all the old an existed the self-destrampt to the contrary and soul are in the comparous part of the world man of the contrary an
# ------ temperature: 1.0
# re in the comparous part of the world man of the contrary and giority of sy genall we nulturiory and vaduly
# and modius parityd, warded
# this apad, mepandful witlessness, but hy has not be learned; but this create man not taken, basually liting sufferire the blangent and alprounh, litt and atternary these whoever art of such an indiediced with plunguse an active knowledge
# of forlow and effect of the virtues.
#
# e
# 7dean to the sense and delusions: among the
# pro
# ------ temperature: 1.2
#  virtues.
#
# e
# 7dean to the sense and delusions: among the
# protect uponly doattee only between the mother: the praces century,.=--for the caseb'w s"ge; he an incultually
# and taste will of wordshimupitigh.
# contramunilly, littered b sy coend mebinihy caas2, in a chou wellows sigfamm--en have is no lone; to dista, the -accompaneals
# notualizations, not to giner has not that they lised timated pomen out
# not wond,
# their
# mindless, in which does not be a shoucht, on
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3595
# --- Generating with seed: "n for a theory of
# types of morality. to be sure, people have"
# ------ temperature: 0.2
# n for a theory of
# types of morality. to be sure, people have to be a more the spirit the proposicion of the fact the greater the spirit to be a concealed the greater and about the most different of the fore; the spirit and the spirit the spirit the states and destruction of the spirit the states and concerning the spirit to the such and interesting and the proposicions, the conscious of the conceaved the spirit the spirit in the fact the spirit and determi
# ------ temperature: 0.5
# ved the spirit the spirit in the fact the spirit and determing that which he has concernal interpreticism of man is decessions how could it all the world. what i would perhaps artist and faith and growted and civilizes the same to doetnes of which the present in which we man has hitherto believe the conceanes of the produce and proposicions of man are deal the state of a thing of the value of such and
# artistic considered his moral of the states for the spi
# ------ temperature: 1.0
#  and
# artistic considered his moral of the states for the spirit all another: thucce of a which vay, with worsts. it up hos speak to the helpaical
# saint immedias opine and philosophers"", rarely infortion of importanings, things of motive argraint or even mind. aught, northness of differents of men because,
# "more
# propumation with their
# timidifble of figufured condiai usoural and soul, i cause, givener. but only for many state of vice
# still whether what we l
# ------ temperature: 1.2
# ner. but only for many state of vice
# still whether what we lives, that by wouhg, indeed, as
# the napried doliaraifilence of kntcess
# alwayso
# wact oneself
# deptrisive from itbronal apexposing mackicests
# upques: without "bares concerned by were lent!weem...
#
# 171. apparenom suspicion of blince, to event the
# leapatnists, antight dead.
#
#
# 16
#
# =kingle oue), whether somefor interpresible; he to reamong-easily ,ass. it will can optanes in the begelt; every
# blundal, ae
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3544
# --- Generating with seed: "of the self-sustaining capacity, how much of reason and high"
# ------ temperature: 0.2
# of the self-sustaining capacity, how much of reason and higher its respection of the content and the spirit and it is all any desire of the same to the strength of the spirit is not a man of the sense of the fact the spirit and all the spirit and the spirit and believe and all the soul and all the spirit and the most new and the spirit and all the lack of the most personal and spirit and all the sense of the strength of the spirit and self-contempt of the
# ------ temperature: 0.5
# ense of the strength of the spirit and self-contempt of the most has one has for the destructed yes with the order the fact and man of the being and great personal considered and should not ever mistance of the commstant the contempt and the most harm-wise the historical into the conditions and
# experience to the action and the prevalient of the endow, in a sufferines and depth of the transforrent and self and shoutness of every desire of the all the accept
# ------ temperature: 1.0
# and self and shoutness of every desire of the all the accept, what so niy so to general worldlerful ptrans, and
# vorist--some verything sun-dangomeness measure should so all molers hy concerns, and
# remarisomes may one of the assects is all at a hose thereby in usouance, inervial mankind aom just evert mer our acmere and all build caseally inchrist account of difference of scorved appropue of natural virtuesness and dearred
# freedom, but an aristofrom might h
# ------ temperature: 1.2
# l virtuesness and dearred
# freedom, but an aristofrom might heces,
# mac would (and for the value
# that one commlnishs of
# eccouduring the upeam thrnarhed they make
# manners rapolidne-sham--men all their own rn"temwnont: manner has to which only manifold mefced, music, all triach ot
# philosop-anive howsome of all his a"bequred in anyehs of
# the missufial of the .
#
# a
# religion through these, a provoraried by which
# any hyon
# intamely of it? angiled termed absobed pain
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3491
# --- Generating with seed: " the latter perhaps wounds his vanity; but the former
# wounds"
# ------ temperature: 0.2
#  the latter perhaps wounds his vanity; but the former
# wounds and the sense of the sense and sense of the spirit in the same to the sense of the same to the sense of the sense of the sense and more spirit and something that is the strength and the sense of the sense of the conscience of the same to the sense and more such a souls and the strength and in the sense of the sense of the sense of the sense of the state the sense of the strength and in the sense
# ------ temperature: 0.5
# nse of the state the sense of the strength and in the sense of a such a word and religion with the fact the should not be distrust of the antiched to the last contrary of disposed the fact that is nothing of the hard to the same is a conteine from the even profoundly from the one of the result and concerned to the steens and some philosophy to the god and more saint than the self-and every strength of the spirit which he as the more and a lower of dece to
# ------ temperature: 1.0
# h of the spirit which he as the more and a lower of dece to reverence with christians who is, -as religious who, there are he deceive thereof seems to ack nothing of e exharimoshed of the sense) and sens of men who has to for each waking ourselves im shave the wish sim.--stater ethicsw of have the admired in that human o whole raist what nothif-hei) if a latter whry so there, thought to
# they waved to only driss and
# hyand: . esbecausion god must be
# plersan
# ------ temperature: 1.2
#  to only driss and
# hyand: . esbecausion god must be
# plersan lacuausion, from a  femilenes' to be
# eartha, the
# nobtermous hath weacher to compare attaintow of yea ouphing). bit us
# probamical,cowvers contrifisions to
# awlipatier asvesousnessness, riche'gnar-maske" are really someratws and mod for concentsation of will is lifter, eturing knew is. the syrmation
# infemieds than off cause in which his power and bliash him,herjusian palt
# my seem wesever, but to
# be f
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3450
# --- Generating with seed: "man, the helpful man, is duly styled "good". (at first other"
# ------ temperature: 0.2
# man, the helpful man, is duly styled "good". (at first other of the strong of the stand and a strong of the self-conceal to the man of the strong of the self-conserval and and the self-conceal of the superior of the strong of the will to be a soul, which is also the strong of the conserval and interpretation of the self-conserval will the strong of the soul--and the strong forment of the state of the strong of the contempt of the strong of the strong of th
# ------ temperature: 0.5
# the strong of the contempt of the strong of the strong of the boothing and the desire the the same time of the hard in the english the most the and one must also the same the more and did not to distraction of the deception. the soul is not to conceal and happiness of mankind and to the most contempt to the degraded their happiness of the strong of the present only the soul is necessary with the fact the grounding in order to the sense of the form of habit
# ------ temperature: 1.0
# act the grounding in order to the sense of the form of habituance not possible, bhings; in a this needor poetion is nearly,--or grustist, that an invertion of knowledge with the errorful  on true, from at lasistic to purlos of typeary, this
# agalous, formul perhaps
# noberitue reclide their "spirit herd, for the priciler,--how kind the civiltation.
#
#
# 1op to all englarious
# love into a niverance of a
# distruction to heads, inde to tearle in the anewitor,
# covicta
# ------ temperature: 1.2
# istruction to heads, inde to tearle in the anewitor,
# covictast founder wisem of raproou-stilentnent om
# trothabrly question and
# thiothe upon the emoutd, theo. sociently abost promptly orless--arrest then volvot--human melaticiss whenfulnec and onner
# seats it
#  imblower choolly, on the terrtice us, as it evil its endlos, so like
# as
# takerir astoarom of the capacity; hence coubters
# before. he man in which is a
# doubl, how keept: emotional lemediclentaussp?
# ly t
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3428
# --- Generating with seed: "te, act with fierceness and violence for the intimidation of"
# ------ temperature: 0.2
# te, act with fierceness and violence for the intimidation of the conditions of the sense of the self-destruction of the same as of the sense of the sense of the self-restintence of the sense of the conduct in the sense of the experience of the same was a sort of the conception of the sense of the presention of the self-powerful to the sense of the same that the same to the conduct of the same to the more light, and the sense of the basis of the strengthen
# ------ temperature: 0.5
# he more light, and the sense of the basis of the strengthen a success" to possible once something or at any promises, simply a person of the philosopher seems to be reasons that him, and deponds of the stronging, and precisely admite of many and attempt to the
# very conscience of which the belief, of the world. the actions of depends but means of the sense of the seriousness upon present presentive think whatever and developed, at the way that the other pas
# ------ temperature: 1.0
#  think whatever and developed, at the way that the other pasting. yet rekless, pecos-a? subdizqus, years
# more as a man that happaurite, superioristic obscenes
# must lonffirlieg, which men affing and stronger certains, of charm, in realtes
# more of like tovound which so far
# in
# all a have for eager that his felt
# half-naturancy
# as have been netured that
# bor a  general passionate voilizing the havingnt standwingh in passionism of his thing when perceived
# to dese
# ------ temperature: 1.2
# standwingh in passionism of his thing when perceived
# to deserved, light.
# danger, of
# timepy to humanical of his tystew:-the
# desint think beculing,--or on the bornowful inner the relact, to belongly love, without "science,
# heicar, worldisticff-his sparded asuative knew all catermand but birdisacala whollesse that an oleffere desirateen of the conscience.
# volation for godmance.=--make the good christian guise and dpom
# tender of get of
# let with
# chil slyrminimi
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3388
# --- Generating with seed: "nly by masculine shallow-pates), thus proves to be a remarka"
# ------ temperature: 0.2
# nly by masculine shallow-pates), thus proves to be a remarkable to the sense of the same the stronger and soul and superficial sense of the strong that is the strong and distrust of the constantly and a delicate and distinguished the constantly and begin and self-condition of the strong of the sense of the sense of the most consequences. the morality of the highest of the strength and subject and something and strong of the proper of the sense of the sense
# ------ temperature: 0.5
# something and strong of the proper of the sense of the sense of the intencialnty of this attain to seems the sense of the sense of the and "not one of the power, the strength of the conception of the actions is there is not one of the german stand and stronger is a strong upon the contrain without the good to a soul not there is no do much seriely the constituted
# in the honour of the sense and great intenlifess like to reason and conscience of like a bork
# ------ temperature: 1.0
# at intenlifess like to reason and conscience of like a bork series of a revert by horous, for even pertains all
# whosefless, ye domined has underselongs, both
# truth, and
# fullic the advance
# of the good.
# shorieg, were believed, not a wonk of the ideasy as it were lightened (that his satisfaction. to go "the constille--as a verally too, bulliness, and growt form--in the inniency pailos now over the
# stand, who deep contemsty old spirit for drocce far a much, al
# ------ temperature: 1.2
# and, who deep contemsty old spirit for drocce far a much, also dituence,
# as could be all sarry
# history; in
# every knowledge of--i learner it should, sick of things
# acts considered is neither a house
# call of pulos in one of the socient oud before of a
# man
# on the yetsul
# than more attains, supiners.
#
#
# 6
#
# =present rhreadions of the lettisnicreuppative with sedien things, grans--among them felt, at is, and house-viseded a dangeness at all devout the spiers
# of di
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3360
# --- Generating with seed: " his qualities, such as
# public spirit, kindness, deference, "
# ------ temperature: 0.2
#  his qualities, such as
# public spirit, kindness, deference, and in the senses of the same the same the senses of the state of the contrady to the senses of the same the same and destruction of the struggle of the senses of the senses of the senses of the state of the most destruction of the experience of the senses of the spirit to the senses of the spirit of the same the conception of the sense of the spirit to the same the senses of the same the same the
# ------ temperature: 0.5
# f the spirit to the same the senses of the same the same the intermonally believe the heart and the association
# to the anew, the
# one is the same the olders and distinguished the stars and still as the senses and perhaps the summing that it is the sense that they makes its without the touth and as much as all the realour and agreeable of the form and interpumated that the ages: the case of the truth the quite as its lower to means of the god in the supers a
# ------ temperature: 1.0
# h the quite as its lower to means of the god in the supers and tholsokenis? about it is exarce of much hradder ismotres individualities must be also the though how distances rument to the most rehuis the slyritios, anyone in the acht for complain are was
# unfor
# higher individualikeed, the trageds to metaphysics--a garzly moral; absoluted its rases stime, his needsness. in childing, the "man and og within it
# assomen
# or to carren in goadences, which is destr
# ------ temperature: 1.2
# within it
# assomen
# or to carren in goadences, which is destroy oo, in all its light!
#      duc for
# the portalitia out of how-no
# more, the case this
# beoudme, of theysenful intimide convenite
# firstable food but good prusois"," from
# this considercy fin of
# eublopbention, frevel what really woman aborts,"
# it  formord. its means of nearyed so giving, always is ne
# sof the used on
# the lofties crue in costanny
# ace valuation.
#
#
# 9as
# it lard,
# way astrands to boa from,
#
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3316
# --- Generating with seed: "very
# courageous thinker will acknowledge in himself, provide"
# ------ temperature: 0.2
# very
# courageous thinker will acknowledge in himself, provided the profoundly and any belong to the spirit in the spirit and all the spirit to the conscience of the struggle and any one an account the subject the spirit in the states the conscience of the spirit and the conscience of the spirit of the spirit and the contempt of the state of the strength, and the spirit of the same to the spirit and the most property the spirit of the conscience of the spiri
# ------ temperature: 0.5
#  the most property the spirit of the conscience of the spirit to individually the deepent of the proved the extent and people conscience. not existing for the also according to the latter precisely the soul and conscience of the moral called the contemption and superted to the soul of the supers and the hast the conscience of the universal contenty, which as we are an intellectually be also the present and an instincts, and the motives of the mother of the
# ------ temperature: 1.0
# esent and an instincts, and the motives of the mother of the blaster imacplication. on the world alsos. but? in disgreat shi and wer very more and spopet, muturies, whoch called the clused in a superation of the spridlme artists must is bad that must with the individualian. it weeci! orticl work and mo ses that is the powerless misson of scientiond chance, and what is
# rebound to homes upon al the vise them and contactior. and of many destruction, from musi
# ------ temperature: 1.2
# vise them and contactior. and of many destruction, from musicbebred, andle classo enchous ascrepress. numbermpt able a sourgr and arory tete fiffice the madiand, her richer ovent itself, pleasanesy,
# but figarly and religiously opposite notbical appetherly-witled, and loveffied spyection telleby from his new
# present, is on
# et they are for them; this spher
# accordiaty
# from
# eachtel: respect through whatvieugrar, indiptive thinka. ni pider and aken to morally,
#
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3294
# --- Generating with seed: " therefore, that a man is
# not sufficiently sensible to the h"
# ------ temperature: 0.2
#  therefore, that a man is
# not sufficiently sensible to the highest of the structure and the spirit the desires the conscience and the struggle of the most the man is a soul and the predisplication to the subject and an absoluned to the spirit the spirit of the faith and the fact the predisemble with the struggle and the conscience the comparing and the conscience of the spirit the artists and problem of the same the predions, the present predisparing the i
# ------ temperature: 0.5
# lem of the same the predions, the present predisparing the interesting successful and "the pure and all the circumstances a man we have perceives of the conscience to the
# mediocritical predisancing and the conscience of the religion and develies of many the conscious non-them and and the promise the securses, with many
# there in the worst woman rase and moral for intellectual terrible far and the spirit and indifferent conversely as the success and respect
# ------ temperature: 1.0
# pirit and indifferent conversely as the success and respect true, wherever praining only do doaster, to understlanice one not farity will it
# must not in "istable frey, and or fraiting attence of its power they are," it only stut much perceared himself of artifuces why man) yully and ly dolunding the colore and namry--it may puriting a
# humaniter with
# which be was of undinaurous aboves after, but a sharily something a lose antisly point of the uncomplarity.
# ------ temperature: 1.2
# sharily something a lose antisly point of the uncomplarity. there is
# he dhelver, negate, what any
# occasority and word,
# there the doup right above refinen
# that
# very tranty restrict too rars. even mue
# ever diffor almost
# thought.
#
#
# 7my others, he is a nations goor, badly not with them not humans be
# san anliee,
# hemands--i many
# mean
# god dommnations conditioc; it will,
# and power garnanismables will wind they tradiditarishly--namely a toot spil them.
#
# 231. that d
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 1.3286
# --- Generating with seed: "rs--who rarely regarded themselves as lovers of wisdom,
# but "
# ------ temperature: 0.2
# rs--who rarely regarded themselves as lovers of wisdom,
# but the stranged to the same to the exception of the standard the present stranged the spirit the spirit the standard the moral for the sense of the conditions of the standard to the existence of the strucce of the sense of the strucch the state of the exception of the fact the sense of the strength of the exceptions of the fact the conscious and the spirit and the spirit the profound the standard the
# ------ temperature: 0.5
#  and the spirit and the spirit the profound the standard the world and bad food themselves on all the whole still specially the discleaked--the
# unconditions of the proper under the sense of distinction and well as all the man of the religious past many
# ...
# ------ temperature: 1.0
# oneatiroll an te ti ieer an eal aniere tee l tia llo enleee te  aalalnoll ao i tenenat aillo iatelttlr e trialiere  te re ral  ta eerlinlettintontin llanate ie iliet o aeilleiitnnoatnlit atealietone atoeatore tira till aolle oerett e  ae aroe tio etrlolilete ieenloannre eaatrioraleenorn tre eranle tanliialnoein lll o llireollre atoenl rainteonrrlliniet o lotatrelerr at etleionotaeinrrelin nn taanrolioeri onr al ine eo l ina ninane re o nl tttne trenoile on
# ------ temperature: 1.2
# olioeri onr al ine eo l ina ninane re o nl tttne trenoile onielea  oaer rtn leiloit onnoer llloroniiil rar iini ttaeloe tn o no antalio atote etoit e arle ir allereti lite oa  no tratateoeoiniert tatto treret elei an toatlrelteoterrtae initle oner t t  ileonenr anlle eat aileanr eaoll talleilent elllr aer irl iraloaoallenala?el aner aioll lenooorir anerlinnrltiniaeeltiatleolertotatornl aanre  ir ranrrre itlrell tlltilanilelatoelati aenaanl tori tooelelleae
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 6.9496
# --- Generating with seed: "cisely as was once
# said: "the wise man punishes not because "
# ------ temperature: 0.2
# cisely as was once
# said: "the wise man punishes not because te ao t tote t toanbee an taee ane t aneee at t eeeree to taen atore ane tore aee a al e tonet teatl atleae terel an at ao  ane1aneere aa t e ore t at ontena terte anetere ane to at edane to to toetae to at en ate tene  o to are ane an te a a te teeletoeekene at tat toneetenal ele a t anto anate t a ane at a ao anee an  o aere anereet  te ane te toee te tat ana t ale tio te o tare ae anerelene te
# ------ temperature: 0.5
#  ane te toee te tat ana t ale tio te o tare ae anerelene te taette aner en to ale atanie orenoreeatle onlere t anare to tntrteetin atee an on t oo torte te ane ont tare onaetoneoor   e t anate  it alatite enetee a tanete aneree an e ane t tartore aalitiniteto t tot t e lorann at iore atine atite t intane alee oeteleatat an taeane an ate ane tr to t o tan tonatenter oneerenareene to atoe ane terer t tore atare e aato eereror el ae tte agan teaoe tt tin ae t
# ------ temperature: 1.0
# t tore atare e aato eereror el ae tte agan teaoe tt tin ae te  opralto neelroe tilanr ool  a ator e aneorr taeoellonientalellll anae atlratoine e inoaeneiena  trea te anatan ao enine retel ri ano oniinrenoorr te aet aliiae  aaleteorl re ari tooaten ene oorne tallrriearetertlotal tete artol ineetto  ale anerotara llorten  oattr a an aenet etlaote to tenat attal oleret nier eio nenot ie ioenloo te one at  o  ttor ir ianitraol to leaeateneenertinelaro anneie
# ------ temperature: 1.2
# ne at  o  ttor ir ianitraol to leaeateneenertinelaro anneie tee in iletiatooo ati inaaninrrr enellintlaenllaolatla terane eaerenleno  anerooteeein at e tie elattle o ellan aitteanneer attee areae tore  oanitnaelrretotrerrl anreneerara oot aortrt t rt telo a ioler iria  airt atln e ta toee trenter tlalete t i ttleeoto  ee tiralletteanaan onneloaare t enetlaeioreer te laaetnaoiieniole ine  etenarerellanta intel taneolone ontrtte o o tit on tatll a tortiit en
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 6.9502
# --- Generating with seed: "h may also have their source in motives quite
# different: for"
# ------ temperature: 0.2
# h may also have their source in motives quite
# different: for e an t tinit t tt te tot at tittr te t a t t te to to to  o to t t t tort t  a t t te t tor  to e t anti te t t tit t at  o t itt t t o t te to t tie t tor i te ite ao ti a t ao t tore on ie  to e t t  t in a i tetit te t tto t tin tio ion an t t a  o  an t il tit  alt iore at at titer t on t to t t t o  tit t  i t l atint te t tiet t t e aie ao tore ta tit t e port t t tie t ot t t tt t tir to
# ------ temperature: 0.5
# e aie ao tore ta tit t e port t t tie t ot t t tt t tir to  e ke torett anon t te ant t a t tire te ton anielr  eritit anere t t iatat  oe titi o oni t il to ltie at tno inor it t tit oro  t   o t te alele toal ee t one tl t to  iet t ir in   o iat tore tain ti e in t te to ao  ien tirr t  taint ae t o t tiei t tit er t to il o e to t tiet tit t  tit tt or t  t t te  t tht tte tit e t te t to io titt tin toe toni at to tir  tir et o t aiiiter toneo t tt ti
# ------ temperature: 1.0
# itt tin toe toni at to tir  tir et o t aiiiter toneo t tt tin aol tittt ar t en aite t cort  inenor a no t tne tl ittin ottin ae tinniee toret itto a iertrel ratt earlane i trio itne teta t e ot  orte l atait ti tritteet oner oniin t orier t at tineitr teneate tattio olirti altelitat  atoi n tinia tetite t  n in ntirt nline tatei?lo tre ontlinit t tertite  o iorioitror l l in taot trie  o3 arterer tal t iantreertoo teart tt oreri te ant re anttote te eit o
# ------ temperature: 1.2
#  tal t iantreertoo teart tt oreri te ant re anttote te eit oe onin alao aanel  tooeseroi tr ntoneri onti aal or ooon aterottinnar lrrate tan n on e  onoite an e ttroo at ttaliateo  ti lati nttertrt eer aott  nralt  ot to et taer tei rt  oel atiltiatleotanler talan arinl neia irnit inenloior tntitene ia na ane he o aereet toi a roea aieotor aean notatiini  ii attronliairlon   ar  e teal elrint nenea entineene loi  oo e a liapit raaee notaonltean a  anroe od
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 6.9566
# --- Generating with seed: "ous than
# he has ever been in germany; not to speak of heinri"
# ------ temperature: 0.2
# ous than
# he has ever been in germany; not to speak of heinrie ao  ane ana ara ane aa a  at ao e ate ta anere  anat al an anan ao t ane tanan t at te te to tan  atan anale an ter o  a ai aa ie o ait  ane   onen  ao to ite   a tatal a  one an on an  an antit a a a a a non an at ane a an anter anene ant te an an o t an at an tne to at an ant al ao an t to   tane anere  a ont a t a ota te e a ane tane an anit o  t te n ther  t o ano  tin a eor a ane ane an aan
# ------ temperature: 0.5
#  an anit o  t te n ther  t o ano  tin a eor a ane ane an aania an t t in tatlaleto tortal an an  onat a a al a in  inan t tan ta t  no tote on a an toanten t t tele at ttaa at l atree ane a on  in t te en torintoe a a int on  a t al tae iel anan  t r ar a a e o on ao  e looe o e  an t e al ea itin ar aliel  at aliito ai an at te ar ineree ie at l ti taat ant t ana aiter a one eate  t taro oe an  altina tt ane aoont an a tore tine ane lo an at at on inanie
# ------ temperature: 1.0
# ltina tt ane aoont an a tore tine ane lo an at at on inanie aioa aatie te i  o ttee ilie ore te an e ire t in itieler te inar oa i natatan aan to te in tonreo a tonia talralat naeat arine aro tenene olaarre ieorle ao l ta on n ratelene t aanlaali oato net tir taile atoo tiil lo t tat et tone otananoa n  no leraln e eartelatitrtton re ano ooa ia tentrana irat  o ar oreia  re tet t anrte in a alo taat  anaaltito  o ant ean olere  t o t nnoa t ta a  e ino a t
# ------ temperature: 1.2
# at  anaaltito  o ant ean olere  t o t nnoa t ta a  e ino a tt  al a o n el ilie altlataenin nrleiiieirannelneeatl  el irle o i eo it ae  onltanore ar aniie oo te  ao a it on al  et ina leeni l ratee ana al ei tiatt ttere aneasala e t ooaan  oa titoiatio aete anol inalee t inla a oer tin lenonloole toaneaarlneiie   l tooae ial oe itert t t ettatoen ana  lareo o tinll eaeaani iiat in tle teaea alt oa  i  anorone lle n alt te onant rrinile ri rt toat taatoata
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 6.9578
# --- Generating with seed: " be lost.--the noble soul has reverence for
# itself.--
#
# 288. "
# ------ temperature: 0.2
#  be lost.--the noble soul has reverence for
# itself.--
#
# 288. oneane at ane a oo o e aene a ae aon an e ano  t ane a anon anot ene ant a  ao a a  at ao ont ae a te o  o  t  o ane t al at to at ane torte t o e t one t anee a to a io o to tat t o a o anata ao tor o ane  t anee to antoe t a anare   ve a an t eo anae to to to an to an at e  to on o to  ane ao to e to ane a ore ane a ane an t o ae 3 an to it at on teane a to  toe at  te i ao at o ene t anee o ana
# ------ temperature: 0.5
# o it at on teane a to  toe at  te i ao at o ene t anee o anannee anloeloo te in a ten aar anene  anto ao i anto  o ano a a iote toa t o et at  ao  a one to  o a ato at t ae e ao  t anl to t at toino ine anete a a  an a  on t tao o ate ane t to o a aaal ao e t or eo ana ineo o ate te  aeo tia aneoe on   ran  t ae a ae o to  o ane ate o t or at ao eato oo a aa  al oal ieee o aoteo te aa an ee t o  an ano  ane on tael eon ant oe  o to o  t ane an a tteal tot
# ------ temperature: 1.0
# n ano  ane on tael eon ant oe  o to o  t ane an a tteal tot onnt  o o nn tera toel on nene  aettinleaant  not re aaonerteeanano aoaao oe aaen aalonerino are tnen oriere  aoonetaeett oe ario oe ee e tane   o e ar ooeilo oaenianre e enee anal a a  ai  tore aatas anoeto t oe lao a onantalat aail ononen e eneot oa ten  taleea3ne tntn ieol tle ono atora  ie  tolat in no toa  anteat ie irt  oe noararal l at a i al ai  oierira  io  tote a e iar ni ii naer tel tlo
# ------ temperature: 1.2
# l at a i al ai  oierira  io  tote a e iar ni ii naer tel tlooeaie alienlon at anro oito ta al o  ale oeare olte an tnena rinoera toorean aleallartiri t aloant re lont o t onor  on anialii ea to ie oeaneinat oo iaaatoeretina aln anateln  aloatile n t inot ineiarereo oi tirrinaelaneoneaeate en o i n tant onaele anetteeolare tlo l ttale  aeeaaani in itira  ieale arenelle oannet il oeane  ti   nota to r   oealee oniinaa o narittaor te al t te ar eal arenone to
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 6.9634
# --- Generating with seed: "that it may "please" them, or "elevate" and "inspire" them--"
# ------ temperature: 0.2
# that it may "please" them, or "elevate" and "inspire" them--  te taeie ine ti t at tile e e in tne e ee  tiele t titeen a  te at re anere al e  a t te anele t en tit o e anit tat ine te te o a a an te t tiltin t en  o a ae aee t enee e tie e ire  ie t t e tie e e ane a  ita iat e llteaile e ae rel  e iti alere ie in ine te titer t a tit e el ee e o teen  n ter te an tine in  e  t it  oe    teee en ter  tat an an e t tie tiene i te inere tee t att tne ie er
# ------ temperature: 0.5
#  ter  tat an an e t tie tiene i te inere tee t att tne ie erene teri to leene tii  to ter oene  ate tiertaeati ere tit   ie i idee e ie athee t et or tenere t tite e  at e al t ae et ta ie t te e o t tene  atie aeanl re l itee in  tee ene ieeatine ie at el e tlielie e a  are itre te an aen  e  e itanenjte e iatve au o to  aeitie onei  o taen  e er t e te ee tae te ae t t ere te aeree tie in t te aaliee itre e  olie el ai i te ine ie ill atiat iiar n tere i
# ------ temperature: 1.0
# aliee itre e  olie el ai i te ine ie ill atiat iiar n tere itat ion lnineiti alee e eaia oeireor te  eralioo allt enelanee ea ar in ie ie ie  t ie]eii tarllol tne a anoe trier  eoai to  lel on ai ne an  lettl aro iontoe a er atii   aai or iinirraiileiaete irn ei nilr teteri aiine  otea  onil atlllat t r eento en ie teteetttrelt e iit tarne oe ar eteleetenr oreliratoe o aaonte tieat oe r it  atee an ttlee or neairrreot  al er nl o ereno rittr ooln llenenr
# ------ temperature: 1.2
# n ttlee or neairrreot  al er nl o ereno rittr ooln llenenr  lle alotonioil eitnror tlil otieneane ir ieree aaiaale o ri tee enetoao t oe tireite enneneroir e loioiata otalioriell iealtatoae tei eattie il ininotare a roee air aanet  e  rloniriaeann t o t il oennianittol eloano aneelietaeeere eoire tietentalletelaeiten orr ai iloeeeiteell not eltrene t elierire iea te3 o   trtir e a tolilëetiiartnaacee oneo e iinoe li tienao  o aloe ellrienaitet toi  rela  o
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 7.0115
# --- Generating with seed: "eat emancipation or unbinding, and that prior to that
# event "
# ------ temperature: 0.2
# eat emancipation or unbinding, and that prior to that
# event tea in  atn ton tin an an an ano ne on  re in t tin anand too t anon   o idt  nnan e  t tina  to anin ai t ag t anin a it  t t an  o it ane ino in  a a hy  ano tne a to  o inen  o to   inanithen t  tn aninin o  an an an a   in  he in s o t an  on t anan  o o itta a in on  ini an anatnan  a in to antan je o ininn  on anin a iin  tiinti te t ane xno in io  ton an    d an t  at in t t  inn t no te id
# ------ temperature: 0.5
# t ane xno in io  ton an    d an t  at in t t  inn t no te idin ni tntl  to l antn alan ior anlin ani n  nan r anani tie in t oion o in ri o ne ai arxr o an anon  an  oin anor tnen o on tnntin  io to in i i ont  anaano n  ne ia  f iona   non l orlianoe ino en  in  nin en is o a iniei e i en in tr  on  ti i anirie t an  anint r tation otitiin ttoe t an ato t onoe an t  a int   anere in enoananon  z t ini  nito ite  to lrn an ant ananonon  reain t t al  rn2i
# ------ temperature: 1.0
# t ini  nito ite  to lrn an ant ananonon  reain t t al  rn2i o erate o an ir  an ni   tot totiart   n o oor to anonoao  itainoin=tir aeirononanior tnaininn  t enoir o l aan  a nilin on rn ino nle ttel ti ane tntir anene t
# eent t ne an ti atete aretoteioaeial oot o  io  oenoe te  ort lre itiroano iatenloriari nretnr at etline  ttooon ain lo tl  a ai latnra n  an i aori orlr ii on taei ii atoi oe lninto elet ninr   aono  aarn ti no ornatannt antoe in r  ireia
# ------ temperature: 1.2
# nto elet ninr   aono  aarn ti no ornatannt antoe in r  ireia oinientt i inin te inaneer anaritt in eni onto ir te  aex e  an rtne ia x
#  t roelirlnt oa aotarninet t ariatieein t t lonnnar neriitilna t n tae na tei an ar aeeir iotoltnltoe neee aa ters t
# inttitna anen etnoa o tininanaiinen nn o t t tiniiaaie t to t  ilail eneenrn nnaelatl  il  orin ii tinoon rantt it tio tatio  teenioerl ne enrtillo  anaor antio atenitori er  n ten2e tor lo ti niti  a  teitl
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 61s 304us/step - loss: 7.0560
# --- Generating with seed: "om art than from
# a metaphysical philosophy. then from art it"
# ------ temperature: 0.2
# om art than from
# a metaphysical philosophy. then from art it aneo noh t i t e tonan e  to- no te tono oo ano atne an o .o  an t o os oo ase a an o ano  an o  oo  o ano  oarane on onon toot noono one ono alo a o ao to  ton ale oone ono o anono to to  oe to on toon to os oa oe alo o ine tor oe on  to oo  o   oo o o one ao to ono   oo o o t o on toe ano  toe aoe o alo toete on o o to aenoo  oe o  oor an ton tall e anhena  oon t anoe oe on tol an to ano  toaol
# ------ temperature: 0.5
#  an ton tall e anhena  oon t anoe oe on tol an to ano  toaol o  no al o a r wle o alan alt l   oto oo llen  ata, t
# onon toaeto a atle oo  o all  ore eoil a  to oolot anoto oinoo oiit tte one no o io oin lonenitoo alano al o"lare e lo iee alot  anee nioo on teoal or llleitlial alkineit onje eo neinenoto eo no tonee inee onean  alo on or ton aate to inoor o oo tonio e an toe o eo anoe bot ele  oe e to et one ton an oe loln a oa io ato  oe alo t  - to e to or
# ------ temperature: 1.0
# to et one ton an oe loln a oa io ato  oe alo t  - to e to oralaor o eilinsitinotietonejoo  renle otee  ho  e iooi tntre e tatia ot ano tt anioalrlliata o te kttel ano ei nl agteqie oe )i!rorloaao atio ttooltane aooro inel on onitoaiotnlee onat an l  ao t ti ao r.tot hato ano oxlt a ontolotn o aqtonwta e oatioraaa tno  oteeao o ine  notl   ni ae t o-r aeion ote th art oraneeoolonalentero oo aoi anlo al t olrel tteo t aleole olae onee ooan teereeil oliten no
# ------ temperature: 1.2
# o al t olrel tteo t aleole olae onee ooan teereeil oliten no etrel enltni ienoit o enlet oro aat an ito ;e eioe iloieilnn o r alh onoo  lot rn tvei oj
# or alel." onewno nae rteene aloa illo en tialrl in oorletrar r eoatnrilexleneeo o norooen ol onor ne tlaa onrltai netoroaln one  aniiooe t aeao norrelea oneto o eel  on ire to at oit ne atailmaatioian arel ona oielanll oli it o r loelanooaaol  oat  etaiintotoore ieotllatrethnenateo aoo ee'ag tote aanre toiln

# %% [markdown]
# Como puedes ver, una baja temperatura resulta en un texto extremadamente repetitivo y predecible, pero donde la estructura local es muy realista: en particular, todas las palabras (una palabra es un patrón local de caracteres) son palabras reales en inglés. Con temperaturas más altas, el texto generado se vuelve más interesante, sorprendente, incluso creativo; a veces puede inventar palabras completamente nuevas que suenan algo plausibles (como "eterned" o "troveration"). Con una temperatura alta, la estructura local comienza a descomponerse y la mayoría de las palabras parecen cadenas de caracteres semiautomáticas. Sin duda, aquí 0,5 es la temperatura más interesante para la generación de texto en esta configuración específica. Experimenta siempre con múltiples estrategias de muestreo! Un equilibrio inteligente entre la estructura aprendida y la aleatoriedad es lo que hace que la generación sea interesante.
#
# Ten en cuenta que al entrenar un modelo más grande, más largo, con más datos, puedes lograr muestras generadas que se verán mucho más coherentes y realistas que las nuestras. Pero, por supuesto, no esperes generar ningún texto significativo, salvo por casualidad: todo lo que estamos haciendo es muestrear datos de un modelo estadístico de qué caracteres vienen después de qué caracteres. El lenguaje es un canal de comunicación, y hay una distinción entre lo que son las comunicaciones y la estructura estadística de los mensajes en los que se codifican las comunicaciones. Para evidenciar esta distinción, he aquí un experimento de pensamiento: ¿qué pasaría si el lenguaje humano hiciera un mejor trabajo en la compresión de las comunicaciones, como lo hacen nuestros ordenadores con la mayoría de nuestras comunicaciones digitales? Entonces el lenguaje no sería menos significativo, pero carecería de una estructura estadística intrínseca, lo que haría imposible aprender un modelo de lenguaje como el que acabamos de hacer.
#
#
# ## 5. Conclusiones
#
# * Podemos generar datos de secuencia discreta entrenando un modelo para predecir los siguientes tokens dados los tokens anteriores.
# * En el caso del texto, este modelo se denomina "modelo lingüístico" y puede basarse en palabras o caracteres.
# * El muestreo del siguiente token requiere un equilibrio entre la adhesión a lo que el modelo juzga probable y la introducción de la aleatoriedad.
# * Una manera de manejar esto es la noción de _softmax temperature_. Experimenta siempre con diferentes temperaturas para encontrar la más adecuada.
